# %% [markdown]
# <a href="https://colab.research.google.com/github/catzmat/DATA201-labs/blob/main/Matenje_Week2_HW.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Catherine Matenje
#
# DATA 201
#
# Week 2 Hwk Assignment
#
# Textbook: An Introduciton to Statistical Learning with APplciations in Python
#
# Chapter 2: Statisticl Learning 2.4: Lab - Introduction to Python
#
# Excercises # 8, 9, & 10

# %%
# Mounting Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Question #8 - College Dataset

# %%
# 8(a) Loading the College dataset

import pandas as pd
college = pd.read_csv("/content/drive/MyDrive/MCCOURSES25-26/Fall2026/DATA201/Assignments/Week2Hwk/College.csv")

# %%
# 8(b) Looking at the College data
college
# Out:
#                          Unnamed: 0 Private   Apps  Accept  Enroll  Top10perc  \
# 0      Abilene Christian University     Yes   1660    1232     721         23
# 1                Adelphi University     Yes   2186    1924     512         16
# 2                    Adrian College     Yes   1428    1097     336         22
# 3               Agnes Scott College     Yes    417     349     137         60
# 4         Alaska Pacific University     Yes    193     146      55         16
# ..                              ...     ...    ...     ...     ...        ...
# 772         Worcester State College      No   2197    1515     543          4
# 773               Xavier University     Yes   1959    1805     695         24
# 774  Xavier University of Louisiana     Yes   2097    1915     695         34
# 775                 Yale University     Yes  10705    2453    1317         95
# 776    York College of Pennsylvania     Yes   2989    1855     691         28
#
# ...

# %%
college2 = pd.read_csv(
    "/content/drive/MyDrive/MCCOURSES25-26/Fall2026/DATA201/Assignments/Week2Hwk/College.csv",
    index_col=0) #index_col=0 tells python to take the first column and use it as the datasets index where the first column in the names of the universities
college2
# Out:
#                                Private   Apps  Accept  Enroll  Top10perc  \
# Abilene Christian University       Yes   1660    1232     721         23
# Adelphi University                 Yes   2186    1924     512         16
# Adrian College                     Yes   1428    1097     336         22
# Agnes Scott College                Yes    417     349     137         60
# Alaska Pacific University          Yes    193     146      55         16
# ...                                ...    ...     ...     ...        ...
# Worcester State College             No   2197    1515     543          4
# Xavier University                  Yes   1959    1805     695         24
# Xavier University of Louisiana     Yes   2097    1915     695         34
# Yale University                    Yes  10705    2453    1317         95
# York College of Pennsylvania       Yes   2989    1855     691         28
#
#                                 Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# ...

# %%
# Renaming the first column and set it as the index
college3 = college.rename({'Unnamed: 0': 'College'}, axis=1)
# this code renames the first column "Unamed:0" to College. {} is the dictionary
college3 = college3.set_index('College')
# this code making the column college the dataset's index
college3
# Out:
#                                Private   Apps  Accept  Enroll  Top10perc  \
# College
# Abilene Christian University       Yes   1660    1232     721         23
# Adelphi University                 Yes   2186    1924     512         16
# Adrian College                     Yes   1428    1097     336         22
# Agnes Scott College                Yes    417     349     137         60
# Alaska Pacific University          Yes    193     146      55         16
# ...                                ...    ...     ...     ...        ...
# Worcester State College             No   2197    1515     543          4
# Xavier University                  Yes   1959    1805     695         24
# Xavier University of Louisiana     Yes   2097    1915     695         34
# Yale University                    Yes  10705    2453    1317         95
# York College of Pennsylvania       Yes   2989    1855     691         28
#
#                                 Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# ...

# %%
# Keeping the modified College dataframe
college = college3

# %%
# 8(c) Creating numerical summary of variables in dataset

college.describe() # summazing all numerical data in dataset
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %%
# 8 (d) Preparing for scatterplot matrix

A = college
C = ['Top10perc', 'Apps', 'Enroll']

A[C]
# Out:
#                                 Top10perc   Apps  Enroll
# College
# Abilene Christian University           23   1660     721
# Adelphi University                     16   2186     512
# Adrian College                         22   1428     336
# Agnes Scott College                    60    417     137
# Alaska Pacific University              16    193      55
# ...                                   ...    ...     ...
# Worcester State College                 4   2197     543
# Xavier University                      24   1959     695
# Xavier University of Louisiana         34   2097     695
# Yale University                        95  10705    1317
# York College of Pennsylvania           28   2989     691
#
# [777 rows x 3 columns]

# %%
# Second method

college[['Top10perc', 'Apps', 'Enroll']]
# Out:
#                                 Top10perc   Apps  Enroll
# College
# Abilene Christian University           23   1660     721
# Adelphi University                     16   2186     512
# Adrian College                         22   1428     336
# Agnes Scott College                    60    417     137
# Alaska Pacific University              16    193      55
# ...                                   ...    ...     ...
# Worcester State College                 4   2197     543
# Xavier University                      24   1959     695
# Xavier University of Louisiana         34   2097     695
# Yale University                        95  10705    1317
# York College of Pennsylvania           28   2989     691
#
# [777 rows x 3 columns]

# %%
# 8(d) Creating a scatterplot matrix

pd.plotting.scatter_matrix(
    college[['Top10perc', 'Apps', 'Enroll']]
)
# Out:
# array([[<Axes: xlabel='Top10perc', ylabel='Top10perc'>,
#         <Axes: xlabel='Apps', ylabel='Top10perc'>,
#         <Axes: xlabel='Enroll', ylabel='Top10perc'>],
#        [<Axes: xlabel='Top10perc', ylabel='Apps'>,
#         <Axes: xlabel='Apps', ylabel='Apps'>,
#         <Axes: xlabel='Enroll', ylabel='Apps'>],
#        [<Axes: xlabel='Top10perc', ylabel='Enroll'>,
#         <Axes: xlabel='Apps', ylabel='Enroll'>,
#         <Axes: xlabel='Enroll', ylabel='Enroll'>]], dtype=object)

# %%
# 8(e) Creating side-by-side boxplots of Outstate vs. Private

college.boxplot('Outstate', by='Private')
# Out:
# <Axes: title={'center': 'Outstate'}, xlabel='Private'>

# %%
# 8(f) Creating the Elite variable

college['Elite'] = pd.cut(college['Top10perc'], # pd.cut takes numeical data values and sorts it into groups, in this case "yes" "no" whether the proportion of students from the top 10% of their HS classes exceeds 50%
                          [0, 0.5, 1],
                          labels=['No', 'Yes'])

# %%
# Counting the number of Elite universities there are

college['Elite'].value_counts()
# Out:
# Elite
# Yes    3
# No     0
# Name: count, dtype: int64

# %% [markdown]
# There are 3 elite universities in the data set

# %%
# Creating side-by-side bboxplots of Outstate vs. Elite

college.boxplot('Outstate', by='Elite')
# Out:
# <Axes: title={'center': 'Outstate'}, xlabel='Elite'>

# %% [markdown]
# I expected to see boxplots for both the “No” and “Yes” groups, but I was surprised that no boxplot appeared for the “No” group. I went back through my code to identify the issue but could not immediately figure out what was wrong. I will explore the datasset more in 8h

# %%
# 8 (g) Creating histograms for quantitative variables

#loading
import matplotlib.pyplot as plt

# %%
# Histogram for Room and Board
college['Room.Board'].plot.hist(bins=10)
# Out:
# <Axes: ylabel='Frequency'>

# %%
# Histogram for Books

college['Books'].plot.hist(bins=15)
# Out:
# <Axes: ylabel='Frequency'>

# %%
# Histogrm for Student Faculty Ratio

college['S.F.Ratio'].plot.hist(bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
# Histogram for Graduation rate

college['Grad.Rate'].plot.hist(bins=25)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# Question #9 - Auto Dataset

# %%
# Loading the data set
import pandas as pd
Auto = pd.read_csv("/content/drive/MyDrive/MCCOURSES25-26/Fall2026/DATA201/Assignments/Week2Hwk/Auto.csv", na_values=['?'])

# %%
# Checking dimensions of dataset

Auto.shape
# Out:
# (397, 9)

# %%
# Removing any observations with missing values aka "?" and checking dimensions again

Auto_new = Auto.dropna()
Auto_new.shape
# Out:
# (392, 9)

# %%
Auto=Auto_new

# %%
# 9(a) Identifying quantitative vs. qualitative predictors

#First, checking the variables in the data set

Auto.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'year', 'origin', 'name'],
#       dtype='object')

# %%
Auto.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0  18.0          8         307.0       130.0    3504          12.0    70
# 1  15.0          8         350.0       165.0    3693          11.5    70
# 2  18.0          8         318.0       150.0    3436          11.0    70
# 3  16.0          8         304.0       150.0    3433          12.0    70
# 4  17.0          8         302.0       140.0    3449          10.5    70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %% [markdown]
# Answer for 9(a):
#
# Quantitative Predictors: mpg, cylinders, displacement, horsepower, weight, accelaration and year
#
# Qualitative Predictors:Origin and name

# %%
# 9(b) Finding the range of each quantitative predictor

# Importing numpy
import numpy as np

# %%
# Range for mpg
np.min(Auto['mpg']), np.max(Auto['mpg'])
# Out:
# (9.0, 46.6)

# %%
# Range for cylinder
np.min(Auto['cylinders']), np.max(Auto['cylinders'])
# Out:
# (3, 8)

# %%
# Range for displacement
np.min(Auto['displacement']), np.max(Auto['displacement'])
# Out:
# (68.0, 455.0)

# %%
# Range for horsepower
np.min(Auto['horsepower']), np.max(Auto['horsepower'])
# Out:
# (46.0, 230.0)

# %%
# Range for weight
np.min(Auto['weight']), np.max(Auto['weight'])
# Out:
# (1613, 5140)

# %%
# Range for acceleration
np.min(Auto['acceleration']), np.max(Auto['acceleration'])
# Out:
# (8.0, 24.8)

# %%
# Range for year
np.min(Auto['year']), np.max(Auto['year'])
# Out:
# (70, 82)

# %%
# 9(c) Mean and Standard devition for each quantitative variable

# %%
# Mean and sd of mpg
np.mean(Auto['mpg']), np.std(Auto['mpg'])
# Out:
# (np.float64(23.445918367346938), 7.795045762682584)

# %%
# Mean and sdof cylinders

np.mean(Auto['cylinders']), np.std(Auto['cylinders'])
# Out:
# (np.float64(5.471938775510204), 1.703606114150195)

# %%
# Mean and sd of displacement

np.mean(Auto['displacement']), np.std(Auto['displacement'])
# Out:
# (np.float64(194.41198979591837), 104.51044418133284)

# %%
# Mean and sd of horsepower

np.mean(Auto['horsepower']), np.std(Auto['horsepower'])
# Out:
# (np.float64(104.46938775510205), 38.442032714425984)

# %%
# Mean and sd of weight

np.mean(Auto['weight']), np.std(Auto['weight'])
# Out:
# (np.float64(2977.5841836734694), 848.3184465698364)

# %%
# Mean and sd of acceleration

np.mean(Auto['acceleration']), np.std(Auto['acceleration'])
# Out:
# (np.float64(15.541326530612244), 2.7553429127509963)

# %%
# Mean and sd of year

np.mean(Auto['year']), np.std(Auto['year'])
# Out:
# (np.float64(75.9795918367347), 3.679034899615175)

# %%
# 9(d) Removing the 10th through 85th observations

Auto_subset = Auto.drop(Auto.index[9:85])

# %%
Auto_subset.shape
# Out:
# (316, 9)

# %%
# Creating Summary table
Auto_subset.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  316.000000  316.000000    316.000000  316.000000   316.000000
# mean    24.404430    5.373418    187.240506  100.721519  2935.971519
# std      7.867283    1.654179     99.678367   35.708853   811.300208
# min     11.000000    3.000000     68.000000   46.000000  1649.000000
# 25%     18.000000    4.000000    100.250000   75.000000  2213.750000
# 50%     23.950000    4.000000    145.500000   90.000000  2792.500000
# 75%     30.550000    6.000000    250.000000  115.000000  3508.000000
# max     46.600000    8.000000    455.000000  230.000000  4997.000000
#
#        acceleration        year      origin
# count    316.000000  316.000000  316.000000
# mean      15.726899   77.145570    1.601266
# std        2.693721    3.106217    0.819910
# min        8.500000   70.000000    1.000000
# 25%       14.000000   75.000000    1.000000
# 50%       15.500000   77.000000    1.000000
# ...

# %% [markdown]
# After removing the 10th through 85th osbservations, there are 316 observations remaining. These are the summary stats of the predictors:
#
# mpg: range = 11.0–46.6, mean = 24.40, SD = 7.87
#
# cylinders: range = 3–8, mean = 5.37, SD = 1.65
#
# displacement: range = 68–455, mean = 187.24, SD = 99.68
#
# horsepower: range = 46–230, mean = 100.72, SD = 35.71
#
# weight: range = 1649–4997, mean = 2935.97, SD = 811.30
#
# acceleration: range = 8.5–24.8, mean = 15.73, SD = 2.69
#
# year: range = 70–82, mean = 77.15, SD = 3.11

# %%
# 9 (e) Using full dataset to investigte predictors graphically

# %% [markdown]
# I am curious to understand the relationships between mpg and vehicle weight; and mpg an vehicle cylinders. I will use a scatterplot asnd a boxpot to understand these relationships. I am also interested to see the distribution of gas mileage in the dataset

# %%
# Scatterplot of mpg vs vehicle weight
Auto.plot.scatter('weight', 'mpg')
# Out:
# <Axes: xlabel='weight', ylabel='mpg'>

# %% [markdown]
# Scatterplot of mpg vs vehicle weight: There is a clear negative relationship between vehicle weight and mpg. As vehicle weight increases, mpg decreases which means that heavier vehicles have lower gas mileage while lighter vehicles have higher gas mileage.

# %%
# Boxplot of mpg by cylinders

Auto.boxplot('mpg', by='cylinders')
# Out:
# <Axes: title={'center': 'mpg'}, xlabel='cylinders'>

# %% [markdown]
# Boxplot of mpg by cylinders: The plot shows there there is some relationship between the number of cylinders a vehcile has the the gas mileage. Overall, vehicles with more cylinders appear to have lower mpg. For example, vehicles with 8 cylinders have mpg lower than 20. While vehicles with 4 cylineders have mpg between 25-35.

# %%
# Histogram of mpg

Auto['mpg'].plot.hist(bins=15)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# Histogram of Mpg: The distribution of mpg ranges from around 9 to 47 mpg and is slightl right-skewed. A majority of the values fall between 12 and 30 mpg, with the  peak concentration between 15-20 mph. There are fewer observations beyond 30 mpg which suggest fewer veichles that have higher than average mpg in this data set.

# %% [markdown]
# Answer to question 9(f)
#
# Suppose that we wish to predict gas mileage (mpg) on the basis of the other variables. Do your plots suggest that any of the other variables might be useful in predicting mpg? Justify your answer.
#
# Yes, I believe that my plots suggest that a few of the variables might be useful in predicting mpg, especially vehicle weight and number of cylinders. For example, the boxplot demonstrates that vehicles with more cylinders have lower mpg, while the scatterplot shows a negative relationship where vehicle weight increases as mpg decreases.

# %% [markdown]
# Question # 10 Boston Dataset

# %%
# 10(a) Loading the data set
import pandas as pd
Boston = pd.read_csv("/content/drive/MyDrive/MCCOURSES25-26/Fall2026/DATA201/Assignments/Week2Hwk/Boston.csv")

# %%
# Inspect first few rows of data set

Boston.head()
# Out:
#    Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0           1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1           2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2           3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3           4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4           5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
#
#    tax  ptratio  lstat  medv
# 0  296     15.3   4.98  24.0
# 1  242     17.8   9.14  21.6
# 2  242     17.8   4.03  34.7
# 3  222     18.7   2.94  33.4
# 4  222     18.7   5.33  36.2

# %%
Boston = pd.read_csv("/content/drive/MyDrive/MCCOURSES25-26/Fall2026/DATA201/Assignments/Week2Hwk/Boston.csv",
                     index_col=0)
Boston.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#    lstat  medv
# 1   4.98  24.0
# 2   9.14  21.6
# 3   4.03  34.7
# 4   2.94  33.4
# 5   5.33  36.2

# %%
# 10(b) Checking the dimensions aka number of rows and columns

Boston.shape
# Out:
# (506, 13)

# %%
Boston.columns
# Out:
# Index(['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
#        'ptratio', 'lstat', 'medv'],
#       dtype='object')

# %% [markdown]
# Answer for 10b: The Boston data set contains 506 rows and 13 columns. Each row represents an observation, possible an Boston-area or census tract. The columns represent different characteristics measured for area/census tract.

# %%
# 10(c) cCreating pairwise scatterplots of predictors in the dataset

# %%
# Scatterplot of crime rate vs tax rate

Boston.plot.scatter('tax', 'crim')
# Out:
# <Axes: xlabel='tax', ylabel='crim'>

# %% [markdown]
# Scatterplot of crime rate and tax rate
#
# There doesn't seem to be a clear linear relationship between tax rate and crime rate. Overall. most area with low/medium teax rates have low crime rates as well. Interesting, tax rates around 650-670 seem to have higher observed crim rates and greater variation in crime rates

# %%
# Scatterplot of crime rate vs pupil-teacher ratio

Boston.plot.scatter('ptratio', 'crim')
# Out:
# <Axes: xlabel='ptratio', ylabel='crim'>

# %% [markdown]
# Scatterplot of pupil-teacher ratios and crime rates:
#
# There also doesn't seem to be a clear linear relationship between pupil-teacher ratio and crime rate. Once again, crime rates are low across most pupil-teacher ratios, however there is a small cluster around the pupil-teacher ratio of 20 that has some higehr crime rstes

# %%
# Scatterplot of crime rate vs median home value

Boston.plot.scatter('medv', 'crim')
# Out:
# <Axes: xlabel='medv', ylabel='crim'>

# %% [markdown]
# Scatterplot of home value and crime rates:
# There seems to be a slightl negative association between median home value and crime rate where areas with lower median home values seem to have more crime rates, or at least more variation in crime rates.These areas also seem to have the highest observed crime rates in the data set. On the other hand, crime rates appear to be lower for higher median hom values.

# %% [markdown]
# Answer for 10(d)
#
# Are any of the predictors associated with per capita crime rate? If so, explain the relationship.
#
# As disucssed in my descriptions of the scatteplots above, some predictors seem to be associated with crime rate. Median home value (medv) for example, shows the clearest relationship where higher median home values correspond with lower crime rates. On the other hand, tax rates and pupil-teacher ratio (ptratio) have less clear relationships with crime rates. But, I did observe that many of the highest crime rates seem to happen at higher tax rates and highe pupil-teacher ratio of 20.

# %%
# 10(e) Max ranges for crime, tax, and pupil-teacher ratio for subrubs

Boston[['crim', 'tax', 'ptratio']].idxmax()
# Out:
# crim       381
# tax        489
# ptratio    355
# dtype: int64

# %%
# Summary statistics for crime, tax, and pupil-teacher ratio

Boston[['crim', 'tax', 'ptratio']].describe()
# Out:
#              crim         tax     ptratio
# count  506.000000  506.000000  506.000000
# mean     3.613524  408.237154   18.455534
# std      8.601545  168.537116    2.164946
# min      0.006320  187.000000   12.600000
# 25%      0.082045  279.000000   17.400000
# 50%      0.256510  330.000000   19.050000
# 75%      3.677083  666.000000   20.200000
# max     88.976200  711.000000   22.000000

# %% [markdown]
# Answer for 10(e)
#  Some suburbs in Boston seem to have  high values for crime rates, tax trates and pupil-teacher ratios. For example, suburb 381 has the highest crime rate, suburb 489 has the highest tax rate, and suburb 355 has the highest pupil-teacher ratio. In this dataset, crime rates range from 0.00632 to 88.9762, tax rates range from 187 to 711, and pupil-teacher ratios range from 12.6 to 22.0.

# %%
# 10(f) Number of suburbs that bound the Charles River

Boston['chas'].value_counts()
# Out:
# chas
# 0    471
# 1     35
# Name: count, dtype: int64

# %% [markdown]
# Answer fo 10(g):
#
# 31 suburbs bound the Charles river

# %%
# 10(g) Median pupil-teacher ratio

np.median(Boston['ptratio'])
# Out:
# np.float64(19.05)

# %% [markdown]
# Answer for 10(g)
#
# The median pupil-teacher ratio among towns in ths data set is 19.05.

# %%
# 10(h) Suburb of Boston with lowest median home value

np.min(Boston['medv'])
# Out:
# 5.0

# %%
# Identifying which suburb in the dataet has a value of 5.0 for median hoe income
Boston[Boston['medv'] == np.min(Boston['medv'])]
# Out:
#         crim   zn  indus  chas    nox     rm    age     dis  rad  tax  \
# 399  38.3518  0.0   18.1     0  0.693  5.453  100.0  1.4896   24  666
# 406  67.9208  0.0   18.1     0  0.693  5.683  100.0  1.4254   24  666
#
#      ptratio  lstat  medv
# 399     20.2  30.59   5.0
# 406     20.2  22.98   5.0

# %% [markdown]
# Answer for 10(h)
# Based on my output, there seems to be two suburbs with the lowest median home value of 5.0 not just one suburb. These are subrub 399 and 406. Both suburbs have high crime rates, high tax rates, and high pupil-teacher ratios. These suburbs also have low average numbers of rooms per dwelling.

# %%
# 10(i) Number of suburbs averaging more than 7 rooms

(Boston['rm'] > 7).sum()
# Out:
# np.int64(64)

# %%
# Number of suburbs averaging more than 8 rooms

(Boston['rm'] > 8).sum()
# Out:
# np.int64(13)

# %%
# Looking at suburbs wth more than 8 rooms per dwelling

Boston[Boston['rm'] > 8].describe()
# Out:
#             crim         zn      indus       chas        nox         rm  \
# count  13.000000  13.000000  13.000000  13.000000  13.000000  13.000000
# mean    0.718795  13.615385   7.078462   0.153846   0.539238   8.348538
# std     0.901640  26.298094   5.392767   0.375534   0.092352   0.251261
# min     0.020090   0.000000   2.680000   0.000000   0.416100   8.034000
# 25%     0.331470   0.000000   3.970000   0.000000   0.504000   8.247000
# 50%     0.520140   0.000000   6.200000   0.000000   0.507000   8.297000
# 75%     0.578340  20.000000   6.200000   0.000000   0.605000   8.398000
# max     3.474280  95.000000  19.580000   1.000000   0.718000   8.780000
#
#              age        dis        rad         tax    ptratio      lstat  \
# count  13.000000  13.000000  13.000000   13.000000  13.000000  13.000000
# mean   71.538462   3.430192   7.461538  325.076923  16.361538   4.310000
# std    24.608723   1.883955   5.332532  110.971063   2.410580   1.373566
# ...

# %% [markdown]
# Answer for 10(i):
#
# In total, there are 64 suburbs that have averaged more than 7 rooms per dwelling and 13 suburbs that averaged more than 8 rooms per dwelling. Taking a closer look at the the suburbs averaging more than 8 rooms, Inoticed they have high median home values and lower crime rates. For example, their average median home value is 44.2 and their average crime rate is about 0.72.
